# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as nlp
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# how's it going testing testing

# %%
variable = pd.read_csv (r"/Users/dermotlyons/Downloads/BearIT/Project/c6/c6/c_6_001.csv")

# %%
print (variable)
# Out:
#         -0.368  1.829  0.328  0.099  0.065  0.063  -0.004
# 0       -0.303  1.873  0.236  0.020 -0.002  0.026  -0.004
# 1       -0.228  1.870  0.255  0.008  0.009  0.041  -0.004
# 2       -0.234  1.777  0.265  0.076  0.063  0.087  -0.005
# 3       -0.224  1.702  0.296  0.036  0.067  0.055  -0.005
# 4       -0.233  1.668  0.337 -0.017  0.009 -0.014  -0.004
# ...        ...    ...    ...    ...    ...    ...     ...
# 192309   0.407  2.484 -0.460 -0.036 -0.026 -0.019  -0.004
# 192310   0.451  2.474 -0.445  0.016  0.017  0.029  -0.004
# 192311   0.483  2.462 -0.416  0.015  0.016  0.025  -0.004
# 192312   0.522  2.517 -0.409 -0.056 -0.053 -0.051  -0.004
# 192313   0.575  2.594 -0.407  0.027  0.028  0.030  -0.004
#
# [192314 rows x 7 columns]

# %%
variable.plot()
# Out:
# <Axes: >
